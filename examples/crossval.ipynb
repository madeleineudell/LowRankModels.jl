# %%
using LowRankModels, DataFrames
import Gadfly

m,n,k = 200,200,3
A = randn(m,k)*randn(k,n) + k*sprandn(m,n,.05)
losses = fill(huber(),n)
r = quadreg(.1)
glrm = GLRM(A,losses,r,r,k+2)

function plot(df, xs::Symbol, ys::Array{Symbol}; scale = :linear, filename=None, height=3, width=6)
    dflong = vcat(map(l->stack(df,l,xs),ys)...)
    if scale ==:log
        p = Gadfly.plot(dflong,x=xs,y=:value,color=:variable,Gadfly.Scale.y_log10)
    else
        p = Gadfly.plot(dflong,x=xs,y=:value,color=:variable)
    end 	
    if !(filename==None)
		println("saving figure in $filename")
        Gadfly.draw(Gadfly.PDF(filename, width*Gadfly.inch, height*Gadfly.inch), p) 
	end
	return p
end
# Out:
# ...
# plot (generic function with 1 method)

# %%
println("Computing regularization path")
train_error, test_error, train_time, model_onenorm, reg_params = 
regularization_path(glrm, params=Params(1,50,.0001,.1), reg_params=linspace(3,0,21), verbose=true)
df = DataFrame(train_error = train_error, test_error = test_error,
               train_time = train_time, model_onenorm = model_onenorm, reg_param = reg_params)
# Out:
# Computing regularization path
# flattening observations
# splitting train and test sets
# forming train and test GLRMs
# training model on 35941 samples and testing on 4059
# fitting train GLRM for reg_param 3.0
# Fitting GLRM
# Iteration 10: objective value = 8170.410341730861
# Iteration 20: objective value = 7965.640952529738
# Iteration 30: objective value = 7897.488796557162
# Iteration 40: objective value = 7846.393373896055
# computing mean train and test error for reg_param 3.0:
# 	train error: 0.116756362782131
# 	test error:  0.13528200219985834
# fitting train GLRM for reg_param 2.8499999999999996
# Fitting GLRM
# Iteration 10: objective value = 7625.285849896551
# computing mean train and test error for reg_param 2.8499999999999996:
# 	train error: 0.11662517019503844
# 	test error:  0.13521973660892975
# fitting train GLRM for reg_param 2.7
# Fitting GLRM
# Iteration 10: objective value = 7425.196793253018
# computing mean train and test error for reg_param 2.7:
# ...

# %%
p = plot(df, :reg_param, [:train_error, :test_error], 
scale = :linear) # filename="reg_path2_jnb.pdf"
# Out:
# Plot(...)

# %%
p
# Out:
# p not defined
# while loading In[4], in expression starting on line 1

# %%
import Gadfly
dflong = vcat(map(l->stack(df,l,:reg_param), [:train_error, :test_error])...)
p = Gadfly.plot(dflong,x=:reg_param,y=:value,color=:variable)
# Out:
# Plot(...)

# %%
draw(PDF("regpath.pdf", 6inch, 3inch), p)
# Out:
# Cairo must be installed to use the PDF backend.
# while loading In[19], in expression starting on line 1
#
#  in PDF at /Users/madeleine/.julia/v0.3/Compose/src/Compose.jl:128

# %%
import PGFPlots
x = :reg_param
ys = [:train_error, :test_error]
plots = Array(PGFPlots.Linear, length(ys))
for i in length(ys)
    plots[i] = PGFPlots.Linear(df[x], df[ys[i]], legendentry=string(ys[i]))
end
a = PGFPlots.Axis(plots[2], xlabel="Regularization parameter", width="5in")
# Out:
# Error saving as SVG
# ERROR: The pdf generation failed.
#    Be sure your latex libraries are fully up to date!
#    You tried: `lualatex --enable-write18 --output-directory=. tikzpicture`
#
#  in error at error.jl:21
#  in save at /Users/madeleine/.julia/v0.3/TikzPictures/src/TikzPictures.jl:135
#  in save at /Users/madeleine/.julia/v0.3/TikzPictures/src/TikzPictures.jl:179
#  in writemime at /Users/madeleine/.julia/v0.3/TikzPictures/src/TikzPictures.jl:211
#  in writemime at /Users/madeleine/.julia/v0.3/PGFPlots/src/PGFPlots.jl:310
#  in sprint at iostream.jl:229
#  in display_dict at /Users/madeleine/.julia/v0.3/IJulia/src/execute_request.jl:31

# %%
PGFPlots.save("regpath.tex", a)

# %%
df = copy(df)
# Out:
# 20x5 DataFrame
# | Row | train_error | test_error | train_time | model_onenorm | reg_param |
# |-----|-------------|------------|------------|---------------|-----------|
# | 1   | 0.276013    | 0.351639   | 70.9905    | 528.931       | 20.0      |
# | 2   | 0.276013    | 0.351639   | 97.4225    | 528.931       | 18.9474   |
# | 3   | 0.276013    | 0.351639   | 120.814    | 528.931       | 17.8947   |
# | 4   | 0.268761    | 0.343662   | 159.083    | 531.118       | 16.8421   |
# | 5   | 0.242047    | 0.313957   | 200.888    | 539.425       | 15.7895   |
# | 6   | 0.208163    | 0.274166   | 249.788    | 550.07        | 14.7368   |
# | 7   | 0.197336    | 0.260908   | 294.443    | 553.498       | 13.6842   |
# | 8   | 0.17417     | 0.231389   | 323.826    | 561.118       | 12.6316   |
# | 9   | 0.165072    | 0.219465   | 359.448    | 564.211       | 11.5789   |
# | 10  | 0.127756    | 0.162367   | 467.433    | 571.261       | 10.5263   |
# ...
